# %% [markdown]
# # Extranccción datos covid Colombia

# %%
# Librerias


## librerias de analisis
import pandas as pd
import numpy as np

## librerias para conexiones
import requests
from sodapy import Socrata

## librerias de tiempo
from datetime import date, timedelta

#librerias para exportar resumenes a excel
from pandas import ExcelWriter

## librerias para realizar graficas de analisis de datos
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.express as px
import cufflinks as cf

init_notebook_mode(connected = True)
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
# ...

# %%
## Conexion datos API

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("www.datos.gov.co", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(www.datos.gov.co,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# se calcula los datos para 5 millon es de filas
results = client.get("gt2j-8ykr", limit=10000000)

# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
df
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 0          6/3/2020 0:00:00          1      2/3/2020 0:00:00           11
# 1          9/3/2020 0:00:00          2      6/3/2020 0:00:00           76
# 2          9/3/2020 0:00:00          3      7/3/2020 0:00:00            5
# 3         11/3/2020 0:00:00          4      9/3/2020 0:00:00            5
# 4         11/3/2020 0:00:00          5      9/3/2020 0:00:00            5
# ...                     ...        ...                   ...          ...
# 5069639  30/11/2021 0:00:00    5069680    12/11/2021 0:00:00           44
# 5069640  30/11/2021 0:00:00    5069681    12/11/2021 0:00:00           25
# 5069641  30/11/2021 0:00:00    5069682    11/11/2021 0:00:00           25
# 5069642  30/11/2021 0:00:00    5069683     6/11/2021 0:00:00           44
# 5069643  30/11/2021 0:00:00    5069684     1/11/2021 0:00:00        47001
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
# Se verifican las columnas

df.columns
# Out:
# Index(['fecha_reporte_web', 'id_de_caso', 'fecha_de_notificaci_n',
#        'departamento', 'departamento_nom', 'ciudad_municipio',
#        'ciudad_municipio_nom', 'edad', 'unidad_medida', 'sexo',
#        'fuente_tipo_contagio', 'ubicacion', 'estado', 'pais_viajo_1_cod',
#        'pais_viajo_1_nom', 'recuperado', 'fecha_inicio_sintomas',
#        'fecha_diagnostico', 'fecha_recuperado', 'tipo_recuperacion',
#        'per_etn_', 'nom_grupo_', 'fecha_muerte', 'Contagios', 'Lugar', 'Edad',
#        'Mayores_Hombres', 'Mayores_Mujeres'],
#       dtype='object')

# %%
contarFilas = df['id_de_caso'].count()
contarFilas
# Out:
# 5069644

# %%
#Se verifican el tipo de datos y si tiene nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5069644 entries, 0 to 5069643
# Data columns (total 23 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   fecha_reporte_web      object
#  1   id_de_caso             object
#  2   fecha_de_notificaci_n  object
#  3   departamento           object
#  4   departamento_nom       object
#  5   ciudad_municipio       object
#  6   ciudad_municipio_nom   object
#  7   edad                   object
#  8   unidad_medida          object
#  9   sexo                   object
#  10  fuente_tipo_contagio   object
#  11  ubicacion              object
#  12  estado                 object
#  13  pais_viajo_1_cod       object
#  14  pais_viajo_1_nom       object
#  15  recuperado             object
#  16  fecha_inicio_sintomas  object
#  17  fecha_diagnostico      object
#  18  fecha_recuperado       object
#  19  tipo_recuperacion      object
#  20  per_etn_               object
# ...

# %%
# Se agrega nueva columna para saber contagios y otra para despues depurar el departamento

df['Contagios'] = 1
df['Lugar'] = df['departamento_nom']

# %% [markdown]
# ### Estandarización nombres departamentos¶

# %%
#Se estandatiza el nombre de los departamentos


df['Lugar'].replace(
    to_replace=['BOGOTA'],
    value='SANTAFE DE BOGOTA D.C',
    inplace=True
)


df['Lugar'].replace(
    to_replace=['BARRANQUILLA'],
    value='ATLANTICO',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['ATLANTICO'],
    value='ATLANTICO',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['VALLE'],
    value='VALLE DEL CAUCA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['CARTAGENA'],
    value='BOLIVAR',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Antioquia'],
    value='ANTIOQUIA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Nariño'],
    value='NARIÑO',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Cundinamarca'],
    value='CUNDINAMARCA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Amazonas'],
    value='AMAZONAS',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Sucre'],
    value='SUCRE',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Chocó'],
    value='CHOCO',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Buenaventura D.E.'],
    value='VALLE DEL CAUCA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Meta'],
    value='META',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Cesar'],
    value='CESAR',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['STA MARTA D.E.'],
    value='MAGDALENA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Córdoba'],
    value='CORDOBA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Bolívar'],
    value='BOLIVAR',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Tolima'],
    value='TOLIMA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Santander'],
    value='SANTANDER',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Magdalena'],
    value='MAGDALENA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['GUAJIRA'],
    value='LA GUAJIRA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Risaralda'],
    value='RISARALDA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Cauca'],
    value='CAUCA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Boyacá'],
    value='BOYACA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Norte de Santander'],
    value='NORTE DE SANTANDER',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Huila'],
    value='HUILA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Caldas'],
    value='CALDAS',
    inplace=True
)


df['Lugar'].replace(
    to_replace=['Quindío'],
    value='QUINDIO',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Arauca'],
    value='ARAUCA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Casanare'],
    value='CASANARE',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Caquetá'],
    value='CAQUETA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Guaviare'],
    value='GUAVIARE',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Putumayo'],
    value='PUTUMAYO',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Vaupés'],
    value='VAUPES',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['SAN ANDRES'],
    value='ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA CATALINA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Guainía'],
    value='GUAINIA',
    inplace=True
)

df['Lugar'].replace(
    to_replace=['Vichada'],
    value='VICHADA',
    inplace=True
)

# %% [markdown]
# ### Estandarización genero

# %%
# Se estandariza el genero

df['sexo'].replace(
    to_replace=['f'],
    value='F',
    inplace=True
)

df['sexo'].replace(
    to_replace=['m'],
    value='M',
    inplace=True

)

df['sexo'].replace(
    to_replace=['M'],
    value='Masculino',
    inplace=True
)

df['sexo'].replace(
    to_replace=['F'],
    value='Femenino',
    inplace=True
)

# %% [markdown]
# ### Estandarización atención

# %%
# en columna recuperado, se estandariza

df['recuperado'].replace(
    to_replace=['fallecido'],
    value='Fallecido',
    inplace=True
)

#Se ve la sumatoria de los estados, según columna recuperado

Estado = df.groupby(['recuperado']).sum().reset_index()
Estado
# Out:
#    recuperado  Contagios
# 0      Activo      13890
# 1   Fallecido     128528
# 2         N/A      17654
# 3  Recuperado    4909572

# %%
#Se conviente edad string a numerico

df['Edad'] = pd.to_numeric(df["edad"])

# %%
df['Mayores_Hombres'] = 0
df['Mayores_Mujeres'] = 0

# %%
def Mayores():
    for i in range(contarFilas):
        if df['sexo'][i] == 'Masculino' and df['Edad'][i]>=18:
            df['Mayores_Hombres'][i] = 1
        elif df['sexo'][i] == 'Femenino' and df['Edad'][i]>=18:
            df['Mayores_Mujeres'][i] = 1
    return df
Mayores()
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 0          6/3/2020 0:00:00          1      2/3/2020 0:00:00           11
# 1          9/3/2020 0:00:00          2      6/3/2020 0:00:00           76
# 2          9/3/2020 0:00:00          3      7/3/2020 0:00:00            5
# 3         11/3/2020 0:00:00          4      9/3/2020 0:00:00            5
# 4         11/3/2020 0:00:00          5      9/3/2020 0:00:00            5
# ...                     ...        ...                   ...          ...
# 5069639  30/11/2021 0:00:00    5069680    12/11/2021 0:00:00           44
# 5069640  30/11/2021 0:00:00    5069681    12/11/2021 0:00:00           25
# 5069641  30/11/2021 0:00:00    5069682    11/11/2021 0:00:00           25
# 5069642  30/11/2021 0:00:00    5069683     6/11/2021 0:00:00           44
# 5069643  30/11/2021 0:00:00    5069684     1/11/2021 0:00:00        47001
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
df['Menores_Hombres'] = 0
df['Menores_Mujeres'] = 0

# %%
def Menores():
    for i in range(contarFilas):
        if df['sexo'][i] == 'Masculino' and df['Edad'][i]<18:
            df['Menores_Hombres'][i] = 1
        elif df['sexo'][i] == 'Femenino' and df['Edad'][i]<18:
            df['Menores_Mujeres'][i] = 1
    return df
Menores()
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 0          6/3/2020 0:00:00          1      2/3/2020 0:00:00           11
# 1          9/3/2020 0:00:00          2      6/3/2020 0:00:00           76
# 2          9/3/2020 0:00:00          3      7/3/2020 0:00:00            5
# 3         11/3/2020 0:00:00          4      9/3/2020 0:00:00            5
# 4         11/3/2020 0:00:00          5      9/3/2020 0:00:00            5
# ...                     ...        ...                   ...          ...
# 5069639  30/11/2021 0:00:00    5069680    12/11/2021 0:00:00           44
# 5069640  30/11/2021 0:00:00    5069681    12/11/2021 0:00:00           25
# 5069641  30/11/2021 0:00:00    5069682    11/11/2021 0:00:00           25
# 5069642  30/11/2021 0:00:00    5069683     6/11/2021 0:00:00           44
# 5069643  30/11/2021 0:00:00    5069684     1/11/2021 0:00:00        47001
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
# Se crea una nueva columna, si es fallecido, coloque 1, de lo contrario, coloca 0

df['Fallecidos'] = 0

def fallecidos():
    for i in range(contarFilas):
        if df['recuperado'][i] == 'Fallecido':
            df['Fallecidos'][i] = 1
    return df
fallecidos()
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 0          6/3/2020 0:00:00          1      2/3/2020 0:00:00           11
# 1          9/3/2020 0:00:00          2      6/3/2020 0:00:00           76
# 2          9/3/2020 0:00:00          3      7/3/2020 0:00:00            5
# 3         11/3/2020 0:00:00          4      9/3/2020 0:00:00            5
# 4         11/3/2020 0:00:00          5      9/3/2020 0:00:00            5
# ...                     ...        ...                   ...          ...
# 5069639  30/11/2021 0:00:00    5069680    12/11/2021 0:00:00           44
# 5069640  30/11/2021 0:00:00    5069681    12/11/2021 0:00:00           25
# 5069641  30/11/2021 0:00:00    5069682    11/11/2021 0:00:00           25
# 5069642  30/11/2021 0:00:00    5069683     6/11/2021 0:00:00           44
# 5069643  30/11/2021 0:00:00    5069684     1/11/2021 0:00:00        47001
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
# Se crea una nueva columna, si es fallecido, coloque 1, de lo contrario, coloca 0

df['Recuperados'] = 0

def recuperados():
    for i in range(contarFilas):
        if df['recuperado'][i] == 'Recuperado':
            df['Recuperados'][i] = 1
    return df
recuperados()
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 0          6/3/2020 0:00:00          1      2/3/2020 0:00:00           11
# 1          9/3/2020 0:00:00          2      6/3/2020 0:00:00           76
# 2          9/3/2020 0:00:00          3      7/3/2020 0:00:00            5
# 3         11/3/2020 0:00:00          4      9/3/2020 0:00:00            5
# 4         11/3/2020 0:00:00          5      9/3/2020 0:00:00            5
# ...                     ...        ...                   ...          ...
# 5069639  30/11/2021 0:00:00    5069680    12/11/2021 0:00:00           44
# 5069640  30/11/2021 0:00:00    5069681    12/11/2021 0:00:00           25
# 5069641  30/11/2021 0:00:00    5069682    11/11/2021 0:00:00           25
# 5069642  30/11/2021 0:00:00    5069683     6/11/2021 0:00:00           44
# 5069643  30/11/2021 0:00:00    5069684     1/11/2021 0:00:00        47001
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
df['Activo'] = 0

def activo():
    for i in range(contarFilas):
        if df['recuperado'][i] == 'Activo':
            df['Activo'][i] = 1
    return df
activo()
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 0          6/3/2020 0:00:00          1      2/3/2020 0:00:00           11
# 1          9/3/2020 0:00:00          2      6/3/2020 0:00:00           76
# 2          9/3/2020 0:00:00          3      7/3/2020 0:00:00            5
# 3         11/3/2020 0:00:00          4      9/3/2020 0:00:00            5
# 4         11/3/2020 0:00:00          5      9/3/2020 0:00:00            5
# ...                     ...        ...                   ...          ...
# 5069639  30/11/2021 0:00:00    5069680    12/11/2021 0:00:00           44
# 5069640  30/11/2021 0:00:00    5069681    12/11/2021 0:00:00           25
# 5069641  30/11/2021 0:00:00    5069682    11/11/2021 0:00:00           25
# 5069642  30/11/2021 0:00:00    5069683     6/11/2021 0:00:00           44
# 5069643  30/11/2021 0:00:00    5069684     1/11/2021 0:00:00        47001
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
# En las casillas con datos vacios, se coloca 0

df = df.fillna(0)

# %%
# Los datos vacios en la columna recuperado, se colocan como sin clasificar

df['recuperado'].replace(
    to_replace=['N/A'],
    value='Sin clasificar',
    inplace=True
)

sin = df[df['recuperado'] == 'Sin clasificar']
sin
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 790       30/3/2020 0:00:00        791     26/3/2020 0:00:00           76
# 928        1/4/2020 0:00:00        929     27/3/2020 0:00:00           25
# 1977       8/4/2020 0:00:00       1978      3/4/2020 0:00:00            5
# 2797      13/4/2020 0:00:00       2798     10/4/2020 0:00:00        47001
# 2858      14/4/2020 0:00:00       2859     11/4/2020 0:00:00        13001
# ...                     ...        ...                   ...          ...
# 5057863  25/11/2021 0:00:00    5057904    15/10/2021 0:00:00            8
# 5058431  26/11/2021 0:00:00    5058472    13/11/2021 0:00:00           17
# 5059810  26/11/2021 0:00:00    5059851    23/11/2021 0:00:00           11
# 5059858  26/11/2021 0:00:00    5059899    13/11/2021 0:00:00           68
# 5062855  27/11/2021 0:00:00    5062896      7/6/2021 0:00:00           11
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
df['Pendiente'] = 0

def pendiente():
    for i in range(contarFilas):
        if df['recuperado'][i] == 'Sin clasificar':
            df['Pendiente'][i] = 1
    return df
pendiente()
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 0          6/3/2020 0:00:00          1      2/3/2020 0:00:00           11
# 1          9/3/2020 0:00:00          2      6/3/2020 0:00:00           76
# 2          9/3/2020 0:00:00          3      7/3/2020 0:00:00            5
# 3         11/3/2020 0:00:00          4      9/3/2020 0:00:00            5
# 4         11/3/2020 0:00:00          5      9/3/2020 0:00:00            5
# ...                     ...        ...                   ...          ...
# 5069639  30/11/2021 0:00:00    5069680    12/11/2021 0:00:00           44
# 5069640  30/11/2021 0:00:00    5069681    12/11/2021 0:00:00           25
# 5069641  30/11/2021 0:00:00    5069682    11/11/2021 0:00:00           25
# 5069642  30/11/2021 0:00:00    5069683     6/11/2021 0:00:00           44
# 5069643  30/11/2021 0:00:00    5069684     1/11/2021 0:00:00        47001
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
suma_contagios = sum(df['Contagios'])
suma_contagios
# Out:
# 5069644

# %%
suma_fallecidos = sum(df['Fallecidos'])
suma_fallecidos
# Out:
# 128528

# %%
suma_recuperados = sum(df['Recuperados'])
suma_recuperados
# Out:
# 4909572

# %%
suma_activos = sum(df['Activo'])
suma_activos
# Out:
# 13890

# %%
# Se crear resumen por departamento, diferentes estados y se calculan los porcentajes de participación

Depar = df.groupby(['Lugar']).sum().reset_index()

Depar['% contagios'] = Depar['Contagios']/suma_contagios
Depar['% fallecidos'] = Depar['Fallecidos']/suma_fallecidos
Depar['% recuperados'] = Depar['Recuperados']/suma_recuperados
Depar['% activos'] = Depar['Activo']/suma_activos
Depar
# Out:
#                                                 Lugar  Contagios      Edad  \
# 0                                            AMAZONAS       6909    260135
# 1                                           ANTIOQUIA     770045  30047238
# 2                                              ARAUCA      14076    545782
# 3   ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA...       8095    328110
# 4                                           ATLANTICO     339144  13485169
# 5                                             BOLIVAR     160512   6259455
# 6                                              BOYACA     106372   4227011
# 7                                              CALDAS     101280   4182836
# 8                                             CAQUETA      22996    921404
# 9                                            CASANARE      35921   1335991
# 10                                              CAUCA      56848   2324461
# ...

# %%
# Se coloca la infromación que se necesita del analisis

Departamento = pd.concat([Depar['Lugar'], Depar['Contagios'], Depar['% contagios'],  Depar['Fallecidos'], Depar['% fallecidos'], Depar['Recuperados'], Depar['% recuperados'], Depar['Activo'], Depar['% activos'], Depar['Pendiente']], axis=1)

Departamento.columns = ['Departamento', 'Contagios', '% contagiados','Fallecidos', '% fallecidos', 'Recuperados', '% recuperados', 'Activos', '% activos', 'Pendientes clasificar']

Departamento
# Out:
#                                          Departamento  Contagios  \
# 0                                            AMAZONAS       6909
# 1                                           ANTIOQUIA     770045
# 2                                              ARAUCA      14076
# 3   ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA...       8095
# 4                                           ATLANTICO     339144
# 5                                             BOLIVAR     160512
# 6                                              BOYACA     106372
# 7                                              CALDAS     101280
# 8                                             CAQUETA      22996
# 9                                            CASANARE      35921
# 10                                              CAUCA      56848
# 11                                              CESAR      91792
# 12                                              CHOCO      16502
# ...

# %%
# Se crear resumen por departamento y municipios con diferentes estados

Mun = df.groupby(['Lugar', 'ciudad_municipio_nom']).sum().reset_index()

# %%
# Se crear resumen por departamento, diferentes estados y se calculan los porcentajes de participación

Mun['% contagios'] = Mun['Contagios']/suma_contagios
Mun['% fallecidos'] = Mun['Fallecidos']/suma_fallecidos
Mun['% recuperados'] = Mun['Recuperados']/suma_recuperados
Mun['% activos'] = Mun['Activo']/suma_activos
Mun
# Out:
#          Lugar ciudad_municipio_nom  Contagios    Edad  Mayores_Hombres  \
# 0     AMAZONAS      EL ENCANTO (CD)          6     186                5
# 1     AMAZONAS     LA CHORRERA (CD)         31    1178               23
# 2     AMAZONAS      LA PEDRERA (CD)        100    4095               39
# 3     AMAZONAS              LETICIA       6486  244377             3109
# 4     AMAZONAS   MIRITI PARANA (CD)         21    1066               13
# ...        ...                  ...        ...     ...              ...
# 1125    VAUPES        YAVARATE (CD)         42    1583               20
# 1126   VICHADA             CUMARIBO        266    9923              122
# 1127   VICHADA         LA PRIMAVERA        154    5750               90
# 1128   VICHADA       PUERTO CARREÑO       2453   90097             1362
# 1129   VICHADA        SANTA ROSALIA        134    4774               73
#
#       Mayores_Mujeres  Menores_Hombres  Menores_Mujeres  Fallecidos  \
# ...

# %%
Municipio = pd.concat([Mun['Lugar'], Mun['ciudad_municipio_nom'], Mun['Contagios'], Mun['% contagios'], Mun['Fallecidos'], Mun['% fallecidos'], Mun['Recuperados'], Mun['% fallecidos'], Mun['Activo'], Mun['% activos'],Mun['Pendiente']], axis=1)

Municipio.columns = ['Departamento', 'Municipio', 'Contagios', '% contagios', 'Fallecidos', '% fallecidos', 'Recuperados', '% fallecidos', 'Activos', '% activos', 'Pendientes clasificar']

Municipio
# Out:
#      Departamento           Municipio  Contagios  % contagios  Fallecidos  \
# 0        AMAZONAS     EL ENCANTO (CD)          6     0.000001           0
# 1        AMAZONAS    LA CHORRERA (CD)         31     0.000006           3
# 2        AMAZONAS     LA PEDRERA (CD)        100     0.000020           4
# 3        AMAZONAS             LETICIA       6486     0.001279         239
# 4        AMAZONAS  MIRITI PARANA (CD)         21     0.000004           0
# ...           ...                 ...        ...          ...         ...
# 1125       VAUPES       YAVARATE (CD)         42     0.000008           0
# 1126      VICHADA            CUMARIBO        266     0.000052           9
# 1127      VICHADA        LA PRIMAVERA        154     0.000030           5
# 1128      VICHADA      PUERTO CARREÑO       2453     0.000484          37
# 1129      VICHADA       SANTA ROSALIA        134     0.000026           2
#
#       % fallecidos  Recuperados  % fallecidos  Activos  % activos  \
# ...

# %%
# Se exporta datos para menores de 18 años

datos_ninez = df[df['Edad']<18]
datos_ninez
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 78        17/3/2020 0:00:00         79     14/3/2020 0:00:00           76
# 98        18/3/2020 0:00:00         99     16/3/2020 0:00:00           73
# 190       21/3/2020 0:00:00        191     21/3/2020 0:00:00           76
# 322       24/3/2020 0:00:00        323     19/3/2020 0:00:00           17
# 431       25/3/2020 0:00:00        432     23/3/2020 0:00:00           76
# ...                     ...        ...                   ...          ...
# 5069586  30/11/2021 0:00:00    5069627    15/11/2021 0:00:00           86
# 5069589  30/11/2021 0:00:00    5069630    15/11/2021 0:00:00           44
# 5069592  30/11/2021 0:00:00    5069633    15/11/2021 0:00:00           44
# 5069623  30/11/2021 0:00:00    5069664    14/11/2021 0:00:00           25
# 5069638  30/11/2021 0:00:00    5069679    12/11/2021 0:00:00           25
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
# Se crear resumen por departamento con diferentes estados con menores de 18 años

Depar_ni = datos_ninez.groupby(['Lugar']).sum().reset_index()

Depar_ni['% contagios'] = Depar_ni['Contagios']/suma_contagios
Depar_ni['% fallecidos'] = Depar_ni['Fallecidos']/suma_fallecidos
Depar_ni['% recuperados'] = Depar_ni['Recuperados']/suma_recuperados
Depar_ni['% activos'] = Depar_ni['Activo']/suma_activos
Depar_ni
# Out:
#                                                 Lugar  Contagios     Edad  \
# 0                                            AMAZONAS        807     8076
# 1                                           ANTIOQUIA      60361   630446
# 2                                              ARAUCA       1033    10617
# 3   ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA...        529     6059
# 4                                           ATLANTICO      38140   382674
# 5                                             BOLIVAR      16956   173833
# 6                                              BOYACA       8658    96955
# 7                                              CALDAS       7718    85947
# 8                                             CAQUETA       1682    17457
# 9                                            CASANARE       2660    28943
# 10                                              CAUCA       4288    45301
# 11                                              CESAR      10209   101836
# ...

# %%
Departamento_niñez = pd.concat([Depar_ni['Lugar'], Depar_ni['Contagios'], Depar_ni['% contagios'], Depar_ni['Fallecidos'], Depar_ni['% fallecidos'], Depar_ni['Recuperados'], Depar_ni['% recuperados'], Depar_ni['Activo'], Depar_ni['% activos'], Depar_ni['Pendiente']], axis=1)

Departamento_niñez.columns = ['Departamento', 'Contagios', '% contagios (comparado frente a todos los contagios no solo menores de edad)', 'Fallecidos', '% fallecidos (comparado frente a todos los fallecidos no solo menores de edad)','Recuperados', '% recuperados (comparado frente a todos los recuperados no solo menores de edad)', 'Activos', '% activos (comparado frente a todos los activos no solo menores de edad)','Pendientes clasificar']

Departamento_niñez
# Out:
#                                          Departamento  Contagios  \
# 0                                            AMAZONAS        807
# 1                                           ANTIOQUIA      60361
# 2                                              ARAUCA       1033
# 3   ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA...        529
# 4                                           ATLANTICO      38140
# 5                                             BOLIVAR      16956
# 6                                              BOYACA       8658
# 7                                              CALDAS       7718
# 8                                             CAQUETA       1682
# 9                                            CASANARE       2660
# 10                                              CAUCA       4288
# 11                                              CESAR      10209
# 12                                              CHOCO       1717
# ...

# %%
# Se crear resumen por departamento y municipios con diferentes estados con menores de 18 años

Mun_ni = datos_ninez.groupby(['Lugar', 'ciudad_municipio_nom']).sum().reset_index()

# %%
Mun_ni['% contagios'] = Mun_ni['Contagios']/suma_contagios
Mun_ni['% fallecidos'] = Mun_ni['Fallecidos']/suma_fallecidos
Mun_ni['% recuperados'] = Mun_ni['Recuperados']/suma_recuperados
Mun_ni['% activos'] = Mun_ni['Activo']/suma_activos
Mun_ni
# Out:
#          Lugar ciudad_municipio_nom  Contagios  Edad  Mayores_Hombres  \
# 0     AMAZONAS     LA CHORRERA (CD)          2    27                0
# 1     AMAZONAS      LA PEDRERA (CD)         16   192                0
# 2     AMAZONAS              LETICIA        755  7492                0
# 3     AMAZONAS   MIRITI PARANA (CD)          1    11                0
# 4     AMAZONAS    PUERTO ARICA (CD)          1     4                0
# ...        ...                  ...        ...   ...              ...
# 1102    VAUPES        YAVARATE (CD)          8    80                0
# 1103   VICHADA             CUMARIBO         18   133                0
# 1104   VICHADA         LA PRIMAVERA          5    65                0
# 1105   VICHADA       PUERTO CARREÑO        106  1312                0
# 1106   VICHADA        SANTA ROSALIA         13   183                0
#
#       Mayores_Mujeres  Menores_Hombres  Menores_Mujeres  Fallecidos  \
# ...

# %%
Municipio_niñez = pd.concat([Mun_ni['Lugar'], Mun_ni['ciudad_municipio_nom'], Mun_ni['Contagios'],Mun_ni['% contagios'],Mun_ni['Fallecidos'], Mun_ni['% fallecidos'],Mun_ni['Recuperados'], Mun_ni['% recuperados'],Mun_ni['Activo'], Mun_ni['% activos'],Mun_ni['Pendiente']], axis=1)

Municipio_niñez.columns = ['Departamento', 'Municipio','Contagios','% contagiados (comparado frente a todos los contagios no solo menores de edad)','Fallecidos','% fallecidos (comparado frente a todos los fallecidos no solo menores de edad)','Recuperados','% recuperados (comparado frente a todos los recuperados no solo menores de edad)','Activos', '% activos (comparado frente a todos los activos no solo menores de edad)','Pendientes clasificar']

Municipio_niñez
# Out:
#      Departamento           Municipio  Contagios  \
# 0        AMAZONAS    LA CHORRERA (CD)          2
# 1        AMAZONAS     LA PEDRERA (CD)         16
# 2        AMAZONAS             LETICIA        755
# 3        AMAZONAS  MIRITI PARANA (CD)          1
# 4        AMAZONAS   PUERTO ARICA (CD)          1
# ...           ...                 ...        ...
# 1102       VAUPES       YAVARATE (CD)          8
# 1103      VICHADA            CUMARIBO         18
# 1104      VICHADA        LA PRIMAVERA          5
# 1105      VICHADA      PUERTO CARREÑO        106
# 1106      VICHADA       SANTA ROSALIA         13
#
#       % contagiados (comparado frente a todos los contagios no solo menores de edad)  \
# 0                                          3.945050e-07
# 1                                          3.156040e-06
# 2                                          1.489256e-04
# 3                                          1.972525e-07
# 4                                          1.972525e-07
# ...

# %%
#Se crea variable apra colocar la fecha de reporte

hoy = date.today()-timedelta(days=1)

fecha = hoy.strftime("%Y-%m-%d")
fecha

fechareporte = pd.DataFrame(columns=['Fecha de reporte'],
                  index=range(1))

fechareporte.iloc[0] = (fecha)
fechareporte
# Out:
#   Fecha de reporte
# 0       2021-11-30

# %%
# Se guarda excel con los resumenes creados

with ExcelWriter('0_covid_resumen.xlsx') as writer:
    fechareporte.to_excel(writer, 'Fecha de extracción datos')
    Departamento.to_excel(writer, 'Resumen departamento')
    Municipio.to_excel(writer, 'Resumen municipio')
    Departamento_niñez.to_excel(writer, 'Resumen departamento menor')
    Municipio_niñez.to_excel(writer, 'Resumen municipio menor')

# %%
Municipio_por_genero = pd.concat([Mun['Lugar'], Mun['ciudad_municipio_nom'], Mun['Contagios'], Mun['Mayores_Mujeres'], Mun['Mayores_Hombres'], Mun['Menores_Mujeres'], Mun['Menores_Hombres']], axis=1)

Municipio_por_genero.columns = ['Departamento', 'Municipio','No. De personas', 'No. De mujeres mayores de edad', 'No. De hombres mayores de edad', 'No. De mujeres menores de edad', 'No. De hombres menores de edad']

Municipio_por_genero
# Out:
#      Departamento           Municipio  No. De personas  \
# 0        AMAZONAS     EL ENCANTO (CD)                6
# 1        AMAZONAS    LA CHORRERA (CD)               31
# 2        AMAZONAS     LA PEDRERA (CD)              100
# 3        AMAZONAS             LETICIA             6486
# 4        AMAZONAS  MIRITI PARANA (CD)               21
# ...           ...                 ...              ...
# 1125       VAUPES       YAVARATE (CD)               42
# 1126      VICHADA            CUMARIBO              266
# 1127      VICHADA        LA PRIMAVERA              154
# 1128      VICHADA      PUERTO CARREÑO             2453
# 1129      VICHADA       SANTA ROSALIA              134
#
#       No. De mujeres mayores de edad  No. De hombres mayores de edad  \
# 0                                  1                               5
# 1                                  6                              23
# 2                                 45                              39
# ...

# %%
Mun2 = df.groupby(['Lugar', 'ciudad_municipio_nom', 'recuperado']).sum().reset_index()
Mun2
# Out:
#          Lugar ciudad_municipio_nom      recuperado  Contagios   Edad  \
# 0     AMAZONAS      EL ENCANTO (CD)      Recuperado          6    186
# 1     AMAZONAS     LA CHORRERA (CD)       Fallecido          3    212
# 2     AMAZONAS     LA CHORRERA (CD)      Recuperado         28    966
# 3     AMAZONAS      LA PEDRERA (CD)       Fallecido          4    252
# 4     AMAZONAS      LA PEDRERA (CD)      Recuperado         96   3843
# ...        ...                  ...             ...        ...    ...
# 3571   VICHADA       PUERTO CARREÑO       Fallecido         37   2474
# 3572   VICHADA       PUERTO CARREÑO      Recuperado       2410  87305
# 3573   VICHADA       PUERTO CARREÑO  Sin clasificar          3    132
# 3574   VICHADA        SANTA ROSALIA       Fallecido          2    146
# 3575   VICHADA        SANTA ROSALIA      Recuperado        132   4628
#
#       Mayores_Hombres  Mayores_Mujeres  Menores_Hombres  Menores_Mujeres  \
# ...

# %%
Municipio_por_genero_estado = pd.concat([Mun2['Lugar'], Mun2['ciudad_municipio_nom'], Mun2['recuperado'],Mun2['Contagios'], Mun2['Mayores_Mujeres'], Mun2['Mayores_Hombres'], Mun2['Menores_Mujeres'], Mun2['Menores_Hombres']], axis=1)

Municipio_por_genero_estado.columns = ['Departamento', 'Municipio', 'Estado', 'No. De personas', 'No. De mujeres mayores de edad', 'No. De hombres mayores de edad', 'No. De mujeres menores de edad', 'No. De hombres menores de edad']

Municipio_por_genero_estado
# Out:
#      Departamento         Municipio          Estado  No. De personas  \
# 0        AMAZONAS   EL ENCANTO (CD)      Recuperado                6
# 1        AMAZONAS  LA CHORRERA (CD)       Fallecido                3
# 2        AMAZONAS  LA CHORRERA (CD)      Recuperado               28
# 3        AMAZONAS   LA PEDRERA (CD)       Fallecido                4
# 4        AMAZONAS   LA PEDRERA (CD)      Recuperado               96
# ...           ...               ...             ...              ...
# 3571      VICHADA    PUERTO CARREÑO       Fallecido               37
# 3572      VICHADA    PUERTO CARREÑO      Recuperado             2410
# 3573      VICHADA    PUERTO CARREÑO  Sin clasificar                3
# 3574      VICHADA     SANTA ROSALIA       Fallecido                2
# 3575      VICHADA     SANTA ROSALIA      Recuperado              132
#
#       No. De mujeres mayores de edad  No. De hombres mayores de edad  \
# ...

# %%
# Se guarda excel con los resumenes creados

with ExcelWriter('0_covid_para_info.xlsx') as writer:
    Municipio_por_genero.to_excel(writer, 'resumen gen')
    Municipio_por_genero_estado.to_excel(writer, 'Resumen gen est')

# %%
### Exportar datos de menores de 18 años

with ExcelWriter('1_covid_lista_niñez.xlsx') as writer:
    datos_ninez.to_excel(writer, 'menores de 18')

# %% [markdown]
# ### Graficas de analisis

# %%
## contagios por edad

#g4 = df.groupby( ['Edad'] ).sum().reset_index()
#plt.figure(figsize=(20,20))
#sns.jointplot(data = g4, x = 'Edad', y = 'Contagios', kind="kde", height=7, space=0)
#plt.ylabel('Contagiados por edad')

## fallecidos por edad

#g5 = df[df['recuperado'] == 'Fallecido']
#g6 = g5.groupby( ['Edad'] ).sum().reset_index()

#plt.figure(figsize=(20,20))
#sns.jointplot(data = g6, x = 'Edad', y = 'Fallecidos', kind="kde", height=7, space=0)
#plt.ylabel('Fallecidos por edad')

# %%
## dsitribución estado participantes

#fig = px.pie(df, values='Contagios', names='recuperado', title='Estado contagiados')
#fig.show()

# %%
Solo_Fallecidos = df[df['recuperado'] == 'Fallecido']
Solo_Fallecidos
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 151       20/3/2020 0:00:00        152     18/3/2020 0:00:00           11
# 152       20/3/2020 0:00:00        153     18/3/2020 0:00:00           11
# 156       20/3/2020 0:00:00        157     20/3/2020 0:00:00        47001
# 187       21/3/2020 0:00:00        188     17/3/2020 0:00:00           76
# 196       16/3/2020 0:00:00        197     13/3/2020 0:00:00        13001
# ...                     ...        ...                   ...          ...
# 5066299  29/11/2021 0:00:00    5066340    28/11/2021 0:00:00           68
# 5066304  29/11/2021 0:00:00    5066345    28/11/2021 0:00:00           68
# 5067041  29/11/2021 0:00:00    5067082    17/11/2021 0:00:00           54
# 5067228  29/11/2021 0:00:00    5067269    22/10/2021 0:00:00           54
# 5067286  29/11/2021 0:00:00    5067327    11/10/2021 0:00:00           54
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
# fallecidos por rango de edad y genero

#fig2 = px.histogram(Solo_Fallecidos, 
#              x = 'Edad', 
#              color = 'sexo',
#              title='Fallecidos por Edad y sexo') 
#fig2.show()

# %%
etnia = df.groupby(['Lugar', 'per_etn_', 'nom_grupo_']).sum().reset_index()
etnia
# Out:
#          Lugar per_etn_     nom_grupo_  Contagios    Edad  Mayores_Hombres  \
# 0     AMAZONAS        0              0         15     571                6
# 1     AMAZONAS        1              0        240    8539              141
# 2     AMAZONAS        1     13 DE MAYO          1      47                0
# 3     AMAZONAS        1   ALTO CARDOZO          1      75                0
# 4     AMAZONAS        1         ANDOKE          9     307                3
# ...        ...      ...            ...        ...     ...              ...
# 4985   VICHADA        1         TIKUNA          3      88                1
# 4986   VICHADA        1  VAYA Y VUELVA          1      25                1
# 4987   VICHADA        1           ZENU          1      55                0
# 4988   VICHADA        5              0          8     374                7
# 4989   VICHADA        6              0       2816  103537             1556
#
# ...

# %%
etnia_guiajira = etnia[etnia['Lugar']=='LA GUAJIRA']
etnia_guiajira
# Out:
#            Lugar per_etn_   nom_grupo_  Contagios     Edad  Mayores_Hombres  \
# 2233  LA GUAJIRA        0            0        350    13705              130
# 2234  LA GUAJIRA        1            0        100     3694               41
# 2235  LA GUAJIRA        1     AIPIACHI          1       33                0
# 2236  LA GUAJIRA        1  AIPIOLARAIN          6      216                2
# 2237  LA GUAJIRA        1      AL JOTE          7      351                4
# ...          ...      ...          ...        ...      ...              ...
# 2705  LA GUAJIRA        1         ZENU         43     1860               15
# 2706  LA GUAJIRA        1        wayuu         61     2007               16
# 2707  LA GUAJIRA        2            0          1       34                1
# 2708  LA GUAJIRA        5            0       1777    66946              665
# 2709  LA GUAJIRA        6            0      39997  1547843            16027
#
# ...

# %%
etnia_lista_guiajira = etnia_guiajira['nom_grupo_'].tolist()
etnia_lista_guiajira
# Out:
# [0,
#  0,
#  'AIPIACHI',
#  'AIPIOLARAIN',
#  'AL JOTE',
#  'ALIRAPA',
#  'ALTOPLANO SAN ANTONIO',
#  'ALUATAPAY',
#  'ALUICIRA (ALUISIRRA)',
#  'AMAICHON III',
#  'AMAIKULE',
#  'AMARIJUNA',
#  'AMUCHEN',
#  'AMUCHISHIGOU',
#  'AMULAMANA',
#  'AMURULUBA',
#  'AMUSHICHOW (AMUSHISHOU)',
#  'AMUTKOU',
#  'ANARALITO NUEVO',
#  'ANUACHON JULIAKAT',
#  'ANYINAKAL',
#  'APALASCHON',
#  'APOTOLURU',
#  'APUNIMANA',
#  'ARANGUANSIRA',
#  'ARENA',
#  'ARENALITO',
#  'ARENOSA',
#  'ARITAIMANA',
#  'ARIWOU',
#  'ARROYO LIMON',
#  'ASIJUSHEIN',
#  'ATAMANA',
#  'ATANQUE',
#  'ATAPU',
#  'ATATOW',
#  'ATNAMANA',
#  'ATPANAPOU',
#  'ATPATSIMA',
#  'ATURAIMPA',
#  'ATUSCHOUN',
#  'ATUTULI',
#  'BANGAÑITA',
#  'BOTOCHERRAIN',
#  'CABILDO CARDON',
#  'CABILDO CARRIZAL',
#  'CABILDO LA PAZ',
#  'CACHUYAS',
#  'CALIENTE',
#  'CAMPAMENTO',
#  'CAMPAMENTO-KARRAPUZER-PALMASOL',
#  'CAMPANA',
#  'CAMPO FLORIDO',
#  'CANEGUACAT',
#  'CANEWAKAY',
#  'CAPICHIRAULE',
#  'CARIACHIL',
#  'CARRAIPIA',
# ...

# %%
etnia_lista_guiajira_in = etnia_guiajira[etnia_guiajira['per_etn_'] == '1']
etnia_lista_guiajira_in
# Out:
#            Lugar per_etn_   nom_grupo_  Contagios  Edad  Mayores_Hombres  \
# 2234  LA GUAJIRA        1            0        100  3694               41
# 2235  LA GUAJIRA        1     AIPIACHI          1    33                0
# 2236  LA GUAJIRA        1  AIPIOLARAIN          6   216                2
# 2237  LA GUAJIRA        1      AL JOTE          7   351                4
# 2238  LA GUAJIRA        1      ALIRAPA          1    26                0
# ...          ...      ...          ...        ...   ...              ...
# 2702  LA GUAJIRA        1         YUNA          1    28                0
# 2703  LA GUAJIRA        1    YUNTAMANA          3    62                0
# 2704  LA GUAJIRA        1       YUTAHO          2    65                0
# 2705  LA GUAJIRA        1         ZENU         43  1860               15
# 2706  LA GUAJIRA        1        wayuu         61  2007               16
#
#       Mayores_Mujeres  Menores_Hombres  Menores_Mujeres  Fallecidos  \
# ...

# %%
etnia_contagios_guajira = etnia_lista_guiajira_in.groupby(['Lugar']).sum().reset_index()
etnia_contagios_guajira
# Out:
#         Lugar  Contagios    Edad  Mayores_Hombres  Mayores_Mujeres  \
# 0  LA GUAJIRA       3675  135379             1280             1907
#
#    Menores_Hombres  Menores_Mujeres  Fallecidos  Recuperados  Activo  \
# 0              229              259         137         3517      11
#
#    Pendiente
# 0         10

# %%
etnia_lista_guiajira = etnia_guiajira['nom_grupo_'].count()
etnia_lista_guiajira
# Out:
# 477

# %%
etnia_choco = etnia[etnia['Lugar']=='CHOCO']
etnia_choco
# Out:
#       Lugar per_etn_                     nom_grupo_  Contagios    Edad  \
# 1413  CHOCO        0                              0          7     378
# 1414  CHOCO        1                         ARACHE          2      77
# 1415  CHOCO        1                     BELLAVISTA          1      18
# 1416  CHOCO        1                      BIAKIDURE          1      25
# 1417  CHOCO        1                  BOSSA NAVARRO          1      47
# 1418  CHOCO        1                     BUENAVISTA          1      42
# 1419  CHOCO        1                          CHANU          5     152
# 1420  CHOCO        1                         COCAMA          2      96
# 1421  CHOCO        1                 COCHORRETAMANA          1      23
# 1422  CHOCO        1  COLONSUAMANA-MACULUBO-JUALITA          1      18
# 1423  CHOCO        1                          CUBEO          1      35
# 1424  CHOCO        1                       DOMINICO          2     119
# ...

# %%
etnia_lista_guiajira_ROM = etnia_guiajira[etnia_guiajira['per_etn_'] == '2']
etnia_lista_guiajira_ROM
# Out:
#            Lugar per_etn_ nom_grupo_  Contagios  Edad  Mayores_Hombres  \
# 2707  LA GUAJIRA        2          0          1    34                1
#
#       Mayores_Mujeres  Menores_Hombres  Menores_Mujeres  Fallecidos  \
# 2707                0                0                0           0
#
#       Recuperados  Activo  Pendiente
# 2707            1       0          0

# %%
etnia_lista_guiajira_Raizal = etnia_guiajira[etnia_guiajira['per_etn_'] == '3']
etnia_lista_guiajira_Raizal
# Out:
# Empty DataFrame
# Columns: [Lugar, per_etn_, nom_grupo_, Contagios, Edad, Mayores_Hombres, Mayores_Mujeres, Menores_Hombres, Menores_Mujeres, Fallecidos, Recuperados, Activo, Pendiente]
# Index: []

# %%
etnia_lista_guiajira_palenqueros = etnia_guiajira[etnia_guiajira['per_etn_'] == '4']
etnia_lista_guiajira_palenqueros
# Out:
# Empty DataFrame
# Columns: [Lugar, per_etn_, nom_grupo_, Contagios, Edad, Mayores_Hombres, Mayores_Mujeres, Menores_Hombres, Menores_Mujeres, Fallecidos, Recuperados, Activo, Pendiente]
# Index: []

# %%
etnia_lista_guiajira_afro = etnia_guiajira[etnia_guiajira['per_etn_'] == '5']
etnia_lista_guiajira_afro
# Out:
#            Lugar per_etn_ nom_grupo_  Contagios   Edad  Mayores_Hombres  \
# 2708  LA GUAJIRA        5          0       1777  66946              665
#
#       Mayores_Mujeres  Menores_Hombres  Menores_Mujeres  Fallecidos  \
# 2708              858              117              137          23
#
#       Recuperados  Activo  Pendiente
# 2708         1752       0          2

# %%
indigenas = df[df['per_etn_'] == '1']
indigenas
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 102       18/3/2020 0:00:00        103     18/3/2020 0:00:00        13001
# 127       19/3/2020 0:00:00        128     18/3/2020 0:00:00           25
# 137       20/3/2020 0:00:00        138     17/3/2020 0:00:00           11
# 162       20/3/2020 0:00:00        163     19/3/2020 0:00:00           11
# 284       23/3/2020 0:00:00        285     20/3/2020 0:00:00           76
# ...                     ...        ...                   ...          ...
# 5057812  25/11/2021 0:00:00    5057853     7/11/2021 0:00:00           19
# 5057830  25/11/2021 0:00:00    5057871     5/11/2021 0:00:00           91
# 5057833  25/11/2021 0:00:00    5057874     5/11/2021 0:00:00            8
# 5057851  25/11/2021 0:00:00    5057892    27/10/2021 0:00:00            8
# 5057856  25/11/2021 0:00:00    5057897    24/10/2021 0:00:00           47
#
#         departamento_nom ciudad_municipio    ciudad_municipio_nom edad  \
# ...

# %%
ROMS = df[df['per_etn_'] == '2']
ROMS
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 98505      1/7/2020 0:00:00      98546     23/6/2020 0:00:00           25
# 98540      1/7/2020 0:00:00      98581     24/6/2020 0:00:00           44
# 130322     9/7/2020 0:00:00     130363     30/6/2020 0:00:00           25
# 130357     9/7/2020 0:00:00     130398     28/6/2020 0:00:00        13001
# 164650    15/7/2020 0:00:00     164691      3/7/2020 0:00:00           11
# ...                     ...        ...                   ...          ...
# 4941255   20/9/2021 0:00:00    4941296      6/9/2021 0:00:00           54
# 4941265   20/9/2021 0:00:00    4941306      6/9/2021 0:00:00           54
# 4953381   28/9/2021 0:00:00    4953422     21/9/2021 0:00:00           68
# 5002217  31/10/2021 0:00:00    5002258    16/10/2021 0:00:00           54
# 5002218  31/10/2021 0:00:00    5002259    16/10/2021 0:00:00           54
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
Raizal = df[df['per_etn_'] == '3']
Raizal
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 337       24/3/2020 0:00:00        338     20/3/2020 0:00:00           76
# 1286       4/4/2020 0:00:00       1287     31/3/2020 0:00:00           15
# 2133       9/4/2020 0:00:00       2134     30/3/2020 0:00:00           15
# 2134       9/4/2020 0:00:00       2135     30/3/2020 0:00:00           15
# 2550      11/4/2020 0:00:00       2551      6/4/2020 0:00:00           11
# ...                     ...        ...                   ...          ...
# 1017847  26/10/2020 0:00:00    1017888    20/10/2020 0:00:00           88
# 1018956  26/10/2020 0:00:00    1018997    17/10/2020 0:00:00           88
# 1030907  27/10/2020 0:00:00    1030948      4/9/2020 0:00:00           88
# 1036737  28/10/2020 0:00:00    1036778    20/10/2020 0:00:00           88
# 1039164  28/10/2020 0:00:00    1039205    13/10/2020 0:00:00           88
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
palenqueros = df[df['per_etn_'] == '4']
palenqueros
# Out:
# Empty DataFrame
# Columns: [fecha_reporte_web, id_de_caso, fecha_de_notificaci_n, departamento, departamento_nom, ciudad_municipio, ciudad_municipio_nom, edad, unidad_medida, sexo, fuente_tipo_contagio, ubicacion, estado, pais_viajo_1_cod, pais_viajo_1_nom, recuperado, fecha_inicio_sintomas, fecha_diagnostico, fecha_recuperado, tipo_recuperacion, per_etn_, nom_grupo_, fecha_muerte, Contagios, Lugar, Edad, Mayores_Hombres, Mayores_Mujeres, Menores_Hombres, Menores_Mujeres, Fallecidos, Recuperados, Activo, Pendiente]
# Index: []
#
# [0 rows x 34 columns]

# %%
negros = df[df['per_etn_'] == '5']
negros
# Out:
#           fecha_reporte_web id_de_caso fecha_de_notificaci_n departamento  \
# 1          9/3/2020 0:00:00          2      6/3/2020 0:00:00           76
# 13        13/3/2020 0:00:00         14     10/3/2020 0:00:00           76
# 15        13/3/2020 0:00:00         16     11/3/2020 0:00:00           11
# 125       19/3/2020 0:00:00        126     18/3/2020 0:00:00         8001
# 307       23/3/2020 0:00:00        308     20/3/2020 0:00:00           11
# ...                     ...        ...                   ...          ...
# 5057845  25/11/2021 0:00:00    5057886    29/10/2021 0:00:00           27
# 5057846  25/11/2021 0:00:00    5057887    29/10/2021 0:00:00           27
# 5057847  25/11/2021 0:00:00    5057888    29/10/2021 0:00:00           27
# 5057848  25/11/2021 0:00:00    5057889    29/10/2021 0:00:00           27
# 5057861  25/11/2021 0:00:00    5057902    16/10/2021 0:00:00           19
#
#         departamento_nom ciudad_municipio ciudad_municipio_nom edad  \
# ...

# %%
### Exportar datos por etnia

with ExcelWriter('por_etnias.xlsx') as writer:
    indigenas.to_excel(writer, 'indigenas')
    ROMS.to_excel(writer, 'Roms')
    Raizal.to_excel(writer, 'Raizal')
    palenqueros.to_excel(writer, 'palenqueros')
    negros.to_excel(writer, 'afro')
